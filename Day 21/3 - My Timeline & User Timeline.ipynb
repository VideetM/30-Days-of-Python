# %%
# !pip install pandas

# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %%
consumer_key = "FVxmHgq4SpfM6A0kdN8JRr3Rd"
consumer_secret = "yshimrDc4edmltLhvjOmsaMAv8cf7S5VxgOuY2i17omeccbsLb"
callback_uri = 'oob'
auth = tweepy.OAuthHandler(consumer_key, consumer_secret, callback_uri)
redirect_url = auth.get_authorization_url()
webbrowser.open(redirect_url)
user_pint_input = input("What's the pin value? ")
auth.get_access_token(user_pint_input)
# Out:
# What's the pin value? 2042340
# ('173096823-DTCzZ8oLpEryUWBThUl214Fz9ot2sK2a2HoCglQU',
#  '40dju3pGuQfmnqjEiuuEdNWrelvNoY2P4mR6E7RCF67uk')

# %%
api = tweepy.API(auth)

# %%
me = api.me()
me.screen_name
# Out:
# 'videet_'

# %%
my_timeline = api.home_timeline()
#print(my_timeline)

# %%
columns = set()
allowed_types = [str, int]
tweets_data = []
for status in my_timeline:
    print(status.author.screen_name)
    # print(type(vars(status)))
    status_dict = dict(vars(status))
    keys = status_dict.keys()
    single_tweet_data = {"user": status.user.screen_name, "author": status.author.screen_name}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)
    tweets_data.append(single_tweet_data)

        
header_cols = list(columns)
header_cols.append("user")
header_cols.append('author')
# Out:
# realpython
# backlon
# terimeowki
# reneritchie
# reneritchie
# snacksinthehall
# El_Cranko
# El_Cranko
# 9to5toys
# 9to5toys
# jacknjohnnie
# reneritchie
# reneritchie
# reneritchie
# rxjshi
# MOU5ERAT
# MOU5ERAT
# TingTiding
# 13surroor

# %%
tweets_data
# Out:
# [{'user': 'realpython',
#   'author': 'realpython',
#   'id': 1292909583799853058,
#   'id_str': '1292909583799853058',
#   'text': 'RT @anthonypjshaw: Answer: Yes you can write a Python C extension entirely in Assembly. And it imports. 🤔 Just need to figure out the right…',
#   'source': 'Buffer',
#   'source_url': 'https://buffer.com',
#   'quoted_status_id': 1292646741087416321,
#   'quoted_status_id_str': '1292646741087416321',
#   'retweet_count': 4,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'backlon',
#   'author': 'backlon',
#   'id': 1292909292496986112,
#   'id_str': '1292909292496986112',
#   'text': 'RT @cgartenberg: Well, I’m never gonna top this headline https://t.co/AqvwFaEBe3',
#   'source': 'TweetDeck',
#   'source_url': 'https://about.twitter.com/products/tweetdeck',
#   'quoted_status_id': 1292909003169832961,
#   'quoted_status_id_str': '1292909003169832961',
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'terimeowki',
#   'author': 'terimeowki',
#   'id': 1292908423290294272,
#   'id_str': '1292908423290294272',
#   'text': 'I am so pumped for umbrella academy season 3 FUCKKK',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'lang': 'en'},
#  {'user': 'reneritchie',
#   'author': 'reneritchie',
#   'id': 1292908183380525056,
#   'id_str': '1292908183380525056',
#   'text': 'RT @jareddipane: USPS is a bit of a mess right now, and if things don’t turn around it could make for a very messy Prime Day this year - ht…',
#   'source': 'Tweetbot for iΟS',
#   'source_url': 'http://tapbots.com/tweetbot',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'reneritchie',
#   'author': 'reneritchie',
#   'id': 1292908093148475393,
#   'id_str': '1292908093148475393',
#   'text': 'RT @panzer: Not a fan of this behavior by default. https://t.co/qKbbLiFGEC',
#   'source': 'Tweetbot for iΟS',
#   'source_url': 'http://tapbots.com/tweetbot',
#   'quoted_status_id': 1292822064139841536,
#   'quoted_status_id_str': '1292822064139841536',
#   'retweet_count': 6,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'snacksinthehall',
#   'author': 'snacksinthehall',
#   'id': 1292908085107974159,
#   'id_str': '1292908085107974159',
#   'text': 'RT @ANI: Lebanon government resigns amid outrage over Beirut blast: Reuters',
#   'source': 'Twitter for iPhone',
#   'source_url': 'http://twitter.com/download/iphone',
#   'retweet_count': 538,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'El_Cranko',
#   'author': 'El_Cranko',
#   'id': 1292908015423598593,
#   'id_str': '1292908015423598593',
#   'text': 'RT @WasimFX: @notanyarious More realistic, has better character development, very good cinematography, better acting (even Katrina did well…',
#   'source': 'Twitter for iPad',
#   'source_url': 'http://twitter.com/#!/download/ipad',
#   'retweet_count': 2,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'El_Cranko',
#   'author': 'El_Cranko',
#   'id': 1292908004963020801,
#   'id_str': '1292908004963020801',
#   'text': 'spot on https://t.co/Zxk8xxFEnC',
#   'source': 'Twitter for iPad',
#   'source_url': 'http://twitter.com/#!/download/ipad',
#   'quoted_status_id': 1292903759962505216,
#   'quoted_status_id_str': '1292903759962505216',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'lang': 'en'},
#  {'user': '9to5toys',
#   'author': '9to5toys',
#   'id': 1292907609226383360,
#   'id_str': '1292907609226383360',
#   'text': 'CleanKey helps you avoid germs on doors and buttons: 2-pack now $17 https://t.co/vQrCBXQ8v9',
#   'source': '9to5Toys',
#   'source_url': 'https://www.9to5toys.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': '9to5toys',
#   'author': '9to5toys',
#   'id': 1292907539353526277,
#   'id_str': '1292907539353526277',
#   'text': "Emerson's Sensi Pro HomeKit Thermostat works with Siri at $113 (Save 20%) https://t.co/RMHTHpBGFC by @blairaltland",
#   'source': '9to5Toys',
#   'source_url': 'https://www.9to5toys.com',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'jacknjohnnie',
#   'author': 'jacknjohnnie',
#   'id': 1292907489415933953,
#   'id_str': '1292907489415933953',
#   'text': '@MOU5ERAT Just like SRK getting best jodi award',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'in_reply_to_status_id': 1292905646879195139,
#   'in_reply_to_status_id_str': '1292905646879195139',
#   'in_reply_to_user_id': 719872910593257473,
#   'in_reply_to_user_id_str': '719872910593257473',
#   'in_reply_to_screen_name': 'MOU5ERAT',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'lang': 'en'},
#  {'user': 'reneritchie',
#   'author': 'reneritchie',
#   'id': 1292907285593886720,
#   'id_str': '1292907285593886720',
#   'text': 'RT @jareddipane: Hey friends. Looking for more #freelancers, this time those who want to help me write some streaming services content alon…',
#   'source': 'Tweetbot for iΟS',
#   'source_url': 'http://tapbots.com/tweetbot',
#   'retweet_count': 11,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'reneritchie',
#   'author': 'reneritchie',
#   'id': 1292907190966157319,
#   'id_str': '1292907190966157319',
#   'text': 'RT @molly_knight: If people had worn masks and stayed home and socially distanced whenever they left the house we would have college footba…',
#   'source': 'Tweetbot for iΟS',
#   'source_url': 'http://tapbots.com/tweetbot',
#   'retweet_count': 3262,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'reneritchie',
#   'author': 'reneritchie',
#   'id': 1292907023785484290,
#   'id_str': '1292907023785484290',
#   'text': '🙏🙏🙏 https://t.co/zH0ny9dPP3',
#   'source': 'Tweetbot for iΟS',
#   'source_url': 'http://tapbots.com/tweetbot',
#   'quoted_status_id': 1292905178593554432,
#   'quoted_status_id_str': '1292905178593554432',
#   'retweet_count': 0,
#   'favorite_count': 10,
#   'lang': 'und'},
#  {'user': 'rxjshi',
#   'author': 'rxjshi',
#   'id': 1292906514823421957,
#   'id_str': '1292906514823421957',
#   'text': 'RT @luism8989: La Liga literally invented 3 brand new awards specifically to give to Cristiano Ronaldo as a consolation prize because Messi…',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'retweet_count': 1135,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': 'MOU5ERAT',
#   'author': 'MOU5ERAT',
#   'id': 1292905646879195139,
#   'id_str': '1292905646879195139',
#   'text': '🤣🤣🤣🤣🤣🤣🤣 https://t.co/ZFFak5ht1u',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'quoted_status_id': 1292475051602780160,
#   'quoted_status_id_str': '1292475051602780160',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'und'},
#  {'user': 'MOU5ERAT',
#   'author': 'MOU5ERAT',
#   'id': 1292905456990527488,
#   'id_str': '1292905456990527488',
#   'text': 'Telling https://t.co/gfyXmNgc8w',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'in_reply_to_status_id': 1292904199525552128,
#   'in_reply_to_status_id_str': '1292904199525552128',
#   'in_reply_to_user_id': 719872910593257473,
#   'in_reply_to_user_id_str': '719872910593257473',
#   'in_reply_to_screen_name': 'MOU5ERAT',
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'lang': 'en'},
#  {'user': 'TingTiding',
#   'author': 'TingTiding',
#   'id': 1292905409397719040,
#   'id_str': '1292905409397719040',
#   'text': 'Someone please share the link to the game to this wonderful girl here!!\n\nTIA and ofcourse #GGMU❤️ https://t.co/9c4MPXhC4q',
#   'source': 'Twitter Web App',
#   'source_url': 'https://mobile.twitter.com',
#   'quoted_status_id': 1292904673003868161,
#   'quoted_status_id_str': '1292904673003868161',
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'lang': 'en'},
#  {'user': '13surroor',
#   'author': '13surroor',
#   'id': 1292904914327396354,
#   'id_str': '1292904914327396354',
#   'text': 'RT @artisthetiic: aur bhosdiwalon',
#   'source': 'Twitter for Android',
#   'source_url': 'http://twitter.com/download/android',
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'lang': 'hi'}]

# %%
df = pd.DataFrame(tweets_data, columns = header_cols)
df.head()
# Out:
#                 source               id_str lang in_reply_to_status_id_str  \
# 0               Buffer  1292909583799853058   en                       NaN
# 1            TweetDeck  1292909292496986112   en                       NaN
# 2  Twitter for Android  1292908423290294272   en                       NaN
# 3     Tweetbot for iΟS  1292908183380525056   en                       NaN
# 4     Tweetbot for iΟS  1292908093148475393   en                       NaN
#
#    in_reply_to_user_id  in_reply_to_status_id  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                                                 text in_reply_to_screen_name  \
# 0  RT @anthonypjshaw: Answer: Yes you can write a...                     NaN
# 1  RT @cgartenberg: Well, I’m never gonna top thi...                     NaN
# 2  I am so pumped for umbrella academy season 3 F...                     NaN
# 3  RT @jareddipane: USPS is a bit of a mess right...                     NaN
# 4  RT @panzer: Not a fan of this behavior by defa...                     NaN
#
#   quoted_status_id_str  favorite_count  retweet_count  \
# 0  1292646741087416321               0              4
# 1  1292909003169832961               0              9
# 2                  NaN               1              0
# 3                  NaN               0              1
# 4  1292822064139841536               0              6
#
#                                      source_url  quoted_status_id  \
# 0                            https://buffer.com      1.292647e+18
# 1  https://about.twitter.com/products/tweetdeck      1.292909e+18
# 2           http://twitter.com/download/android               NaN
# 3                   http://tapbots.com/tweetbot               NaN
# 4                   http://tapbots.com/tweetbot      1.292822e+18
#
#   in_reply_to_user_id_str                   id         user       author
# 0                     NaN  1292909583799853058   realpython   realpython
# 1                     NaN  1292909292496986112      backlon      backlon
# 2                     NaN  1292908423290294272   terimeowki   terimeowki
# 3                     NaN  1292908183380525056  reneritchie  reneritchie
# 4                     NaN  1292908093148475393  reneritchie  reneritchie
