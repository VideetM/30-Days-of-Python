# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (2.10)

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
client_id = '4eee37cd028342dfa8a060c82a107635'
client_secret = '07b3561235d940238c5b0cca6df915c9'

# %%
class Spotify_API(object):
    access_token = None
    access_token_expires = datetime.datetime.now() 
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self,client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        
        """
        Returns a base64 encoded string

        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client id and client secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization" : f"Basic {client_creds_b64}"
        }
        
        
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    

    
    def perform_auth(self):
        
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            return Exception("Did not authenticate client")
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    
    
    def get_access_token(self):
        
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token ==None:
            self.perform_auth()
            return self.get_access_token()
        return token 
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
        "Authorization":f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type ='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header() 
        r = requests.get(endpoint,headers = headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self,_id):
        return self.get_resource(_id, resource_type = 'albums')
        
    def get_artist(self,_id):
        return self.get_resource(_id, resource_type = 'artists')
        
    def search(self, query, search_type ='artist'):
        access_token = self.get_access_token()
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({'q': query,'type':search_type.lower()})
        print(data)
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url,headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

# %%
spotify = Spotify_API(client_id, client_secret)

# %%
spotify.search("Bekhayali", search_type="Track")
# Out:
# q=Bekhayali&type=track
# https://api.spotify.com/v1/search?q=Bekhayali&type=track
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bekhayali&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#        'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#        'id': '6WOdPJmexxFINcKMkP2jMG',
#        'name': 'Sachet Tandon',
#        'type': 'artist',
#        'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#        'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#        'id': '1SyKki7JI1AZNKwgNMkn25',
#        'name': 'Sachet-Parampara',
#        'type': 'artist',
#        'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5m5aIc0rrrPUMDARDnQzB9'},
#      'href': 'https://api.spotify.com/v1/albums/5m5aIc0rrrPUMDARDnQzB9',
#      'id': '5m5aIc0rrrPUMDARDnQzB9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27390d98409f70719daa0dc0421',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0290d98409f70719daa0dc0421',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485190d98409f70719daa0dc0421',
#        'width': 64}],
#      'name': 'Bekhayali (From "Kabir Singh")',
#      'release_date': '2019-05-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5m5aIc0rrrPUMDARDnQzB9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#       'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#       'id': '1SyKki7JI1AZNKwgNMkn25',
#       'name': 'Sachet-Parampara',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 371790,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181901739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1feANd8EfcDP5UqSvbheM3'},
#     'href': 'https://api.spotify.com/v1/tracks/1feANd8EfcDP5UqSvbheM3',
#     'id': '1feANd8EfcDP5UqSvbheM3',
#     'is_local': False,
#     'name': 'Bekhayali (From "Kabir Singh")',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5de297ed4b4d56c6d6465f8f6a8f3e2421baaf73?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1feANd8EfcDP5UqSvbheM3'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3uuu6u13U0KeVQsZ3CZKK4'},
#      'href': 'https://api.spotify.com/v1/albums/3uuu6u13U0KeVQsZ3CZKK4',
#      'id': '3uuu6u13U0KeVQsZ3CZKK4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381ec87aeb0de11aee247fbfa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281ec87aeb0de11aee247fbfa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181ec87aeb0de11aee247fbfa',
#        'width': 64}],
#      'name': 'Kabir Singh',
#      'release_date': '2019-06-14',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:3uuu6u13U0KeVQsZ3CZKK4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 371790,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181901739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4yMbbysldl7E3WgiaugnwM'},
#     'href': 'https://api.spotify.com/v1/tracks/4yMbbysldl7E3WgiaugnwM',
#     'id': '4yMbbysldl7E3WgiaugnwM',
#     'is_local': False,
#     'name': 'Bekhayali',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5de297ed4b4d56c6d6465f8f6a8f3e2421baaf73?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4yMbbysldl7E3WgiaugnwM'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#        'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#        'id': '4YRxDV8wJFPHPTeXepOstw',
#        'name': 'Arijit Singh',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#        'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#        'id': '1SyKki7JI1AZNKwgNMkn25',
#        'name': 'Sachet-Parampara',
#        'type': 'artist',
#        'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5OXCK2FlyxVIuLr4BRg0Lw'},
#      'href': 'https://api.spotify.com/v1/albums/5OXCK2FlyxVIuLr4BRg0Lw',
#      'id': '5OXCK2FlyxVIuLr4BRg0Lw',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bbc280510fa8d8c4e30f3b19',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bbc280510fa8d8c4e30f3b19',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bbc280510fa8d8c4e30f3b19',
#        'width': 64}],
#      'name': 'Bekhayali (Arijit Singh Version) [From "Kabir Singh"]',
#      'release_date': '2019-06-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5OXCK2FlyxVIuLr4BRg0Lw'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#       'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#       'id': '1SyKki7JI1AZNKwgNMkn25',
#       'name': 'Sachet-Parampara',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 370444,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181902087'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6aPMWbbdhDhiJHlknZb9Yx'},
#     'href': 'https://api.spotify.com/v1/tracks/6aPMWbbdhDhiJHlknZb9Yx',
#     'id': '6aPMWbbdhDhiJHlknZb9Yx',
#     'is_local': False,
#     'name': 'Bekhayali (Arijit Singh Version) [From "Kabir Singh"]',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c60c5eadb53886c7bf46b5481163b5991b014d08?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6aPMWbbdhDhiJHlknZb9Yx'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3uuu6u13U0KeVQsZ3CZKK4'},
#      'href': 'https://api.spotify.com/v1/albums/3uuu6u13U0KeVQsZ3CZKK4',
#      'id': '3uuu6u13U0KeVQsZ3CZKK4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27381ec87aeb0de11aee247fbfa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0281ec87aeb0de11aee247fbfa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485181ec87aeb0de11aee247fbfa',
#        'width': 64}],
#      'name': 'Kabir Singh',
#      'release_date': '2019-06-14',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:3uuu6u13U0KeVQsZ3CZKK4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 370444,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181902087'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/47Il9B5GJ2FEkiwiIH3xX0'},
#     'href': 'https://api.spotify.com/v1/tracks/47Il9B5GJ2FEkiwiIH3xX0',
#     'id': '47Il9B5GJ2FEkiwiIH3xX0',
#     'is_local': False,
#     'name': 'Bekhayali (Arijit Singh Version)',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c60c5eadb53886c7bf46b5481163b5991b014d08?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:47Il9B5GJ2FEkiwiIH3xX0'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1OPqAyxsQc8mcRmoNBAnVk'},
#        'href': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk',
#        'id': '1OPqAyxsQc8mcRmoNBAnVk',
#        'name': 'Dhvani Bhanushali',
#        'type': 'artist',
#        'uri': 'spotify:artist:1OPqAyxsQc8mcRmoNBAnVk'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#        'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#        'id': '1SyKki7JI1AZNKwgNMkn25',
#        'name': 'Sachet-Parampara',
#        'type': 'artist',
#        'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0kSuatXpK6nUidm8bl2Gfi'},
#      'href': 'https://api.spotify.com/v1/albums/0kSuatXpK6nUidm8bl2Gfi',
#      'id': '0kSuatXpK6nUidm8bl2Gfi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738c0d62cedeabf6b7204c65f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028c0d62cedeabf6b7204c65f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518c0d62cedeabf6b7204c65f9',
#        'width': 64}],
#      'name': 'Bekhayali Acoustic - Dhvani Bhanushali Version (From "T-Series Acoustics")',
#      'release_date': '2019-07-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0kSuatXpK6nUidm8bl2Gfi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1OPqAyxsQc8mcRmoNBAnVk'},
#       'href': 'https://api.spotify.com/v1/artists/1OPqAyxsQc8mcRmoNBAnVk',
#       'id': '1OPqAyxsQc8mcRmoNBAnVk',
#       'name': 'Dhvani Bhanushali',
#       'type': 'artist',
#       'uri': 'spotify:artist:1OPqAyxsQc8mcRmoNBAnVk'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#       'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#       'id': '1SyKki7JI1AZNKwgNMkn25',
#       'name': 'Sachet-Parampara',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 241175,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181904153'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0fcnEPWBnqHKqKsR4JXjAS'},
#     'href': 'https://api.spotify.com/v1/tracks/0fcnEPWBnqHKqKsR4JXjAS',
#     'id': '0fcnEPWBnqHKqKsR4JXjAS',
#     'is_local': False,
#     'name': 'Bekhayali Acoustic - Dhvani Bhanushali Version (From "T-Series Acoustics")',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/50e7145c7b514b14b86542376a723ff99551af04?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0fcnEPWBnqHKqKsR4JXjAS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#        'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#        'id': '4YRxDV8wJFPHPTeXepOstw',
#        'name': 'Arijit Singh',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1WwkojG9sjMSrFVz4D51W0'},
#      'href': 'https://api.spotify.com/v1/albums/1WwkojG9sjMSrFVz4D51W0',
#      'id': '1WwkojG9sjMSrFVz4D51W0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731aa5adad8593923dcdf1a7d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021aa5adad8593923dcdf1a7d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511aa5adad8593923dcdf1a7d0',
#        'width': 64}],
#      'name': 'Ultimate Love Songs - Arijit Singh',
#      'release_date': '2020-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1WwkojG9sjMSrFVz4D51W0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 370444,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181902087'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0AJ6PUJERpXYRGGQQfOrRC'},
#     'href': 'https://api.spotify.com/v1/tracks/0AJ6PUJERpXYRGGQQfOrRC',
#     'id': '0AJ6PUJERpXYRGGQQfOrRC',
#     'is_local': False,
#     'name': 'Bekhayali (Arijit Singh Version) [From "Kabir Singh"]',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8712d6624d84bbc3d858b87e4bb7c66602b72c5b?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0AJ6PUJERpXYRGGQQfOrRC'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#        'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#        'id': '6WOdPJmexxFINcKMkP2jMG',
#        'name': 'Sachet Tandon',
#        'type': 'artist',
#        'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#        'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#        'id': '1E6arsXf5Fgsnv9YpSzjpE',
#        'name': 'Parampara Thakur',
#        'type': 'artist',
#        'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#        'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#        'id': '1SyKki7JI1AZNKwgNMkn25',
#        'name': 'Sachet-Parampara',
#        'type': 'artist',
#        'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5pm6vFHHOD8VPK3UeAbOAU'},
#      'href': 'https://api.spotify.com/v1/albums/5pm6vFHHOD8VPK3UeAbOAU',
#      'id': '5pm6vFHHOD8VPK3UeAbOAU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738a94f0ee6e761d560afe633f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028a94f0ee6e761d560afe633f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518a94f0ee6e761d560afe633f',
#        'width': 64}],
#      'name': 'Bekhayali Reprise (From "T-Series Acoustics")',
#      'release_date': '2019-08-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5pm6vFHHOD8VPK3UeAbOAU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#       'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#       'id': '1E6arsXf5Fgsnv9YpSzjpE',
#       'name': 'Parampara Thakur',
#       'type': 'artist',
#       'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#       'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#       'id': '1SyKki7JI1AZNKwgNMkn25',
#       'name': 'Sachet-Parampara',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212131,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181904491'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1hGZ3udaXm2c2iH7YHDvXv'},
#     'href': 'https://api.spotify.com/v1/tracks/1hGZ3udaXm2c2iH7YHDvXv',
#     'id': '1hGZ3udaXm2c2iH7YHDvXv',
#     'is_local': False,
#     'name': 'Bekhayali Reprise (From "T-Series Acoustics")',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bb5c4bfb4fb94e883db6314d720a016706239ee0?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1hGZ3udaXm2c2iH7YHDvXv'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#        'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#        'id': '4YRxDV8wJFPHPTeXepOstw',
#        'name': 'Arijit Singh',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#        'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#        'id': '1SyKki7JI1AZNKwgNMkn25',
#        'name': 'Sachet-Parampara',
#        'type': 'artist',
#        'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1jPeDHvfU5Knw8VyOP6TZN'},
#        'href': 'https://api.spotify.com/v1/artists/1jPeDHvfU5Knw8VyOP6TZN',
#        'id': '1jPeDHvfU5Knw8VyOP6TZN',
#        'name': 'Dj Chetas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1jPeDHvfU5Knw8VyOP6TZN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1VrkQFKSAfbGPGKA57hI5c'},
#      'href': 'https://api.spotify.com/v1/albums/1VrkQFKSAfbGPGKA57hI5c',
#      'id': '1VrkQFKSAfbGPGKA57hI5c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de856714f100b6d9fac7075d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de856714f100b6d9fac7075d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de856714f100b6d9fac7075d',
#        'width': 64}],
#      'name': 'Bekhayali (Arijit Singh Version) Remix',
#      'release_date': '2020-05-09',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1VrkQFKSAfbGPGKA57hI5c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#       'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#       'id': '4YRxDV8wJFPHPTeXepOstw',
#       'name': 'Arijit Singh',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1SyKki7JI1AZNKwgNMkn25'},
#       'href': 'https://api.spotify.com/v1/artists/1SyKki7JI1AZNKwgNMkn25',
#       'id': '1SyKki7JI1AZNKwgNMkn25',
#       'name': 'Sachet-Parampara',
#       'type': 'artist',
#       'uri': 'spotify:artist:1SyKki7JI1AZNKwgNMkn25'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1jPeDHvfU5Knw8VyOP6TZN'},
#       'href': 'https://api.spotify.com/v1/artists/1jPeDHvfU5Knw8VyOP6TZN',
#       'id': '1jPeDHvfU5Knw8VyOP6TZN',
#       'name': 'Dj Chetas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1jPeDHvfU5Knw8VyOP6TZN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 191912,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS182000907'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Scv9NtqWSdS8gEbPT317u'},
#     'href': 'https://api.spotify.com/v1/tracks/2Scv9NtqWSdS8gEbPT317u',
#     'id': '2Scv9NtqWSdS8gEbPT317u',
#     'is_local': False,
#     'name': 'Bekhayali (Arijit Singh Version) Remix',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab28e74c0de2672aca4b41f5d56cd8501def01d1?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2Scv9NtqWSdS8gEbPT317u'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1T96ULZl0RFzkAAiFEMonG'},
#      'href': 'https://api.spotify.com/v1/albums/1T96ULZl0RFzkAAiFEMonG',
#      'id': '1T96ULZl0RFzkAAiFEMonG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b550391409a0079fd2917d72',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b550391409a0079fd2917d72',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b550391409a0079fd2917d72',
#        'width': 64}],
#      'name': 'Top 20 Most Viewed Songs Of The Decade (2010-2019)',
#      'release_date': '2020-02-06',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:1T96ULZl0RFzkAAiFEMonG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 371790,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181901739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/62gaF6yfhju9yeahhVWZI5'},
#     'href': 'https://api.spotify.com/v1/tracks/62gaF6yfhju9yeahhVWZI5',
#     'id': '62gaF6yfhju9yeahhVWZI5',
#     'is_local': False,
#     'name': 'Bekhayali (From "Kabir Singh")',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5de297ed4b4d56c6d6465f8f6a8f3e2421baaf73?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:62gaF6yfhju9yeahhVWZI5'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Fzx90QzxbSBZrlk4nkxog'},
#        'href': 'https://api.spotify.com/v1/artists/4Fzx90QzxbSBZrlk4nkxog',
#        'id': '4Fzx90QzxbSBZrlk4nkxog',
#        'name': 'SaQi',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Fzx90QzxbSBZrlk4nkxog'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1Ud5TRhEnQwzJ6k7AcKzUn'},
#      'href': 'https://api.spotify.com/v1/albums/1Ud5TRhEnQwzJ6k7AcKzUn',
#      'id': '1Ud5TRhEnQwzJ6k7AcKzUn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27353a87bed8e5c27368f85fa33',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0253a87bed8e5c27368f85fa33',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485153a87bed8e5c27368f85fa33',
#        'width': 64}],
#      'name': 'Bekhayali',
#      'release_date': '2020-08-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1Ud5TRhEnQwzJ6k7AcKzUn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Fzx90QzxbSBZrlk4nkxog'},
#       'href': 'https://api.spotify.com/v1/artists/4Fzx90QzxbSBZrlk4nkxog',
#       'id': '4Fzx90QzxbSBZrlk4nkxog',
#       'name': 'SaQi',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Fzx90QzxbSBZrlk4nkxog'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 71627,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZAMM1915069'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0BnOHWLU9FHijuMdILa6cF'},
#     'href': 'https://api.spotify.com/v1/tracks/0BnOHWLU9FHijuMdILa6cF',
#     'id': '0BnOHWLU9FHijuMdILa6cF',
#     'is_local': False,
#     'name': 'Bekhayali',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/15e99c13fa6eb28deb91c3dbd38975d529befb48?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0BnOHWLU9FHijuMdILa6cF'},
#    {'album': {'album_type': 'single',
# ...
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738435732a527a7731369f10ec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028435732a527a7731369f10ec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518435732a527a7731369f10ec',
#        'width': 64}],
#      'name': 'Charismatic Sasha - Shahid',
#      'release_date': '2020-02-24',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:1q3htYC8esCMF7RjUEJAG6'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 371790,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181901739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5RIjckSyJ8Eb1rrxURxJ5H'},
#     'href': 'https://api.spotify.com/v1/tracks/5RIjckSyJ8Eb1rrxURxJ5H',
#     'id': '5RIjckSyJ8Eb1rrxURxJ5H',
#     'is_local': False,
#     'name': 'Bekhayali (From "Kabir Singh")',
#     'popularity': 5,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5de297ed4b4d56c6d6465f8f6a8f3e2421baaf73?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5RIjckSyJ8Eb1rrxURxJ5H'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0p4qrRSU0xyB6ZLPEZMIv2'},
#      'href': 'https://api.spotify.com/v1/albums/0p4qrRSU0xyB6ZLPEZMIv2',
#      'id': '0p4qrRSU0xyB6ZLPEZMIv2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732f1f7afdc1fbc383fc43a367',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022f1f7afdc1fbc383fc43a367',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512f1f7afdc1fbc383fc43a367',
#        'width': 64}],
#      'name': 'Heartbreak Hits - Tujhe Bhula Diya',
#      'release_date': '2020-04-27',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:0p4qrRSU0xyB6ZLPEZMIv2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 371790,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181901739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7brfcYfvLMDKM4BcKYB1X4'},
#     'href': 'https://api.spotify.com/v1/tracks/7brfcYfvLMDKM4BcKYB1X4',
#     'id': '7brfcYfvLMDKM4BcKYB1X4',
#     'is_local': False,
#     'name': 'Bekhayali (From "Kabir Singh")',
#     'popularity': 1,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df713eb5b0e9538ce4ba8251e657b459e57e1cb0?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7brfcYfvLMDKM4BcKYB1X4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2htGt0uYwCbSVhiSPfP4Is'},
#      'href': 'https://api.spotify.com/v1/albums/2htGt0uYwCbSVhiSPfP4Is',
#      'id': '2htGt0uYwCbSVhiSPfP4Is',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c89f554d65d0f5f8a48430d7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c89f554d65d0f5f8a48430d7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c89f554d65d0f5f8a48430d7',
#        'width': 64}],
#      'name': 'World Music Day 2020 - Top 20',
#      'release_date': '2020-06-20',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:2htGt0uYwCbSVhiSPfP4Is'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 371790,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181901739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Op8KXfVphawiCoClUKnIs'},
#     'href': 'https://api.spotify.com/v1/tracks/2Op8KXfVphawiCoClUKnIs',
#     'id': '2Op8KXfVphawiCoClUKnIs',
#     'is_local': False,
#     'name': 'Bekhayali (From "Kabir Singh")',
#     'popularity': 2,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df713eb5b0e9538ce4ba8251e657b459e57e1cb0?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:2Op8KXfVphawiCoClUKnIs'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5sTpUrYfmtG9cGoWw7oEev'},
#      'href': 'https://api.spotify.com/v1/albums/5sTpUrYfmtG9cGoWw7oEev',
#      'id': '5sTpUrYfmtG9cGoWw7oEev',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cdac28c4b5b511f34e847baf',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cdac28c4b5b511f34e847baf',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cdac28c4b5b511f34e847baf',
#        'width': 64}],
#      'name': 'Melodies Unplugged',
#      'release_date': '2020-05-19',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5sTpUrYfmtG9cGoWw7oEev'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6WOdPJmexxFINcKMkP2jMG'},
#       'href': 'https://api.spotify.com/v1/artists/6WOdPJmexxFINcKMkP2jMG',
#       'id': '6WOdPJmexxFINcKMkP2jMG',
#       'name': 'Sachet Tandon',
#       'type': 'artist',
#       'uri': 'spotify:artist:6WOdPJmexxFINcKMkP2jMG'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1E6arsXf5Fgsnv9YpSzjpE'},
#       'href': 'https://api.spotify.com/v1/artists/1E6arsXf5Fgsnv9YpSzjpE',
#       'id': '1E6arsXf5Fgsnv9YpSzjpE',
#       'name': 'Parampara Thakur',
#       'type': 'artist',
#       'uri': 'spotify:artist:1E6arsXf5Fgsnv9YpSzjpE'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 212131,
#     'explicit': False,
#     'external_ids': {'isrc': 'INS181904491'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0WRqotOw5hgSt1S0P3kAmz'},
#     'href': 'https://api.spotify.com/v1/tracks/0WRqotOw5hgSt1S0P3kAmz',
#     'id': '0WRqotOw5hgSt1S0P3kAmz',
#     'is_local': False,
#     'name': 'Bekhayali Reprise (From "T-Series Acoustics")',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/431f6670330e3361be88cc95d4961e60b30567bc?cid=4eee37cd028342dfa8a060c82a107635',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0WRqotOw5hgSt1S0P3kAmz'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Bekhayali&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 31}}

# %%
spotify.get_artist("4YRxDV8wJFPHPTeXepOstw")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#  'followers': {'href': None, 'total': 16342474},
#  'genres': ['desi pop', 'filmi', 'modern bollywood'],
#  'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#  'id': '4YRxDV8wJFPHPTeXepOstw',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/2ef89fc8ae47fcfd1c4efbdb4135ad6ba9b93fb1',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/eb81a98108c42b4332944336a9acc017d8d89dca',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/aaf5e02bc54b29d3643be598ff9cd405ef4ca363',
#    'width': 160}],
#  'name': 'Arijit Singh',
#  'popularity': 82,
#  'type': 'artist',
#  'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'}

# %%
spotify.get_album("4yMbbysldl7E3WgiaugnwM")
# Out:
# {}
