# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/videet/.local/share/virtualenvs/Day_19-vtOJY-PR/lib/python3.8/site-packages (from requests) (2020.6.20)

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
client_id = ''
client_secret = ''

# %%
class Spotify_API(object):
    access_token = None
    access_token_expires = datetime.datetime.now() 
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self,client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        
        """
        Returns a base64 encoded string

        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client id and client secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization" : f"Basic {client_creds_b64}"
        }
        
        
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    

    
    def perform_auth(self):
        
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] #seconds
        expires = now + datetime.timedelta(seconds = expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True

# %%
spotify = Spotify_API(client_id, client_secret)

# %%
spotify.perform_auth()
# Out:
# True

# %%
access_token = spotify.access_token
access_token
# Out:
# 'BQDcyh8ElseUBKVXAO_32c2an6kcfEkw-RiskV0UWJQqVRqJZ5mZ36WkvD3COQUN-1cyxMMMFaTDctFEkmo'

# %%
"https://api.spotify.com/v1/search?q=tania%20bowra&type=artist" 
headers = {
    "Authorization":f"Bearer {access_token}"
}
endpoint = "https://api.spotify.com/v1/search"
data = urlencode({'q':'arijit','type':'artist'})
print(data)
lookup_url = f"{endpoint}?{data}"
print(lookup_url)
r = requests.get(lookup_url,headers=headers)
print(r.status_code)
# Out:
# q=arijit&type=artist
# https://api.spotify.com/v1/search?q=arijit&type=artist
# 200

# %%
r.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=arijit&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YRxDV8wJFPHPTeXepOstw'},
#     'followers': {'href': None, 'total': 16342474},
#     'genres': ['desi pop', 'filmi', 'modern bollywood'],
#     'href': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw',
#     'id': '4YRxDV8wJFPHPTeXepOstw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2ef89fc8ae47fcfd1c4efbdb4135ad6ba9b93fb1',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/eb81a98108c42b4332944336a9acc017d8d89dca',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/aaf5e02bc54b29d3643be598ff9cd405ef4ca363',
#       'width': 160}],
#     'name': 'Arijit Singh',
#     'popularity': 82,
#     'type': 'artist',
#     'uri': 'spotify:artist:4YRxDV8wJFPHPTeXepOstw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4SCDbi4KztQTP0HoOuCNjK'},
#     'followers': {'href': None, 'total': 594},
#     'genres': ['indian singer-songwriter'],
#     'href': 'https://api.spotify.com/v1/artists/4SCDbi4KztQTP0HoOuCNjK',
#     'id': '4SCDbi4KztQTP0HoOuCNjK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/0ffe1d1c50f59308275bf0218c225f4ce252f106',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/a8ec7f85513b63fca9e3cad5231a8dffd2675753',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/5febfbeacabfacae60fe051880ca6b640289419a',
#       'width': 160}],
#     'name': 'Arijit Anand',
#     'popularity': 22,
#     'type': 'artist',
#     'uri': 'spotify:artist:4SCDbi4KztQTP0HoOuCNjK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4C4llHDLjn86GI1bU9KsoO'},
#     'followers': {'href': None, 'total': 68},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4C4llHDLjn86GI1bU9KsoO',
#     'id': '4C4llHDLjn86GI1bU9KsoO',
#     'images': [],
#     'name': 'Arijit',
#     'popularity': 5,
#     'type': 'artist',
#     'uri': 'spotify:artist:4C4llHDLjn86GI1bU9KsoO'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6BZExpYe5yylgSeHAWVsF6'},
#     'followers': {'href': None, 'total': 74},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6BZExpYe5yylgSeHAWVsF6',
#     'id': '6BZExpYe5yylgSeHAWVsF6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/dda53d6e0ab455073c803f0c6b7ea72718ff33da',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/f198c6738fc839b1d0fb3d92b68d4b8116cbdad8',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/6dca08286f2e41473197b9d43b124100289544c0',
#       'width': 160}],
#     'name': 'Dev Arijit',
#     'popularity': 30,
#     'type': 'artist',
#     'uri': 'spotify:artist:6BZExpYe5yylgSeHAWVsF6'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1dSkvGgh8Zjn1FbfGObpP1'},
#     'followers': {'href': None, 'total': 70},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/
'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LTcWgiPgOfzTJOs7aTuKh'},
#     'followers': {'href': None, 'total': 19},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4LTcWgiPgOfzTJOs7aTuKh',
#     'id': '4LTcWgiPgOfzTJOs7aTuKh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/2bfba875b385f69e08882560ac95c4130681a6a6',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ba391fe6e010eeb20159237eed0f9b2fe8bf2ff6',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/0ac986c911cf474efc36c22fa43139b46535acee',
#       'width': 160}],
#     'name': 'Arijit Nandi',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:4LTcWgiPgOfzTJOs7aTuKh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6D3BHJFeloR62JzgLtZRK7'},
#     'followers': {'href': None, 'total': 5},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6D3BHJFeloR62JzgLtZRK7',
#     'id': '6D3BHJFeloR62JzgLtZRK7',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff083e7fcd1b59661c34755c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff083e7fcd1b59661c34755c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff083e7fcd1b59661c34755c',
#       'width': 64}],
#     'name': 'Arijit Dey',
#     'popularity': 4,
#     'type': 'artist',
#     'uri': 'spotify:artist:6D3BHJFeloR62JzgLtZRK7'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2qbfkH3Ow5GPcANZNHOfSp'},
#     'followers': {'href': None, 'total': 247},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2qbfkH3Ow5GPcANZNHOfSp',
#     'id': '2qbfkH3Ow5GPcANZNHOfSp',
#     'images': [],
#     'name': 'Vishal and Shekhar (Additional Vocals: Arijit Singh)',
#     'popularity': 3,
#     'type': 'artist',
#     'uri': 'spotify:artist:2qbfkH3Ow5GPcANZNHOfSp'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/53HLjaii3ZnTjEhEH2qtL1'},
#     'followers': {'href': None, 'total': 11},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/53HLjaii3ZnTjEhEH2qtL1',
#     'id': '53HLjaii3ZnTjEhEH2qtL1',
#     'images': [],
#     'name': 'Dev Arijit',
#     'popularity': 4,
#     'type': 'artist',
#     'uri': 'spotify:artist:53HLjaii3ZnTjEhEH2qtL1'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/60YJdnHMDSuQpjE06M8iIU'},
#     'followers': {'href': None, 'total': 13},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/60YJdnHMDSuQpjE06M8iIU',
#     'id': '60YJdnHMDSuQpjE06M8iIU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/c21e10ab99714d6df6c298aaaee51a032b22a01d',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/0b3c155b85cc207ae763f37d87ac4dd6cc759754',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/cd677b9b629b7ee232fa2564469256028c0d381b',
#       'width': 160}],
#     'name': 'Arijit Saha',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:60YJdnHMDSuQpjE06M8iIU'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2qVtLLcHemEKfxYe2XjYM9'},
#     'followers': {'href': None, 'total': 9},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/2qVtLLcHemEKfxYe2XjYM9',
#     'id': '2qVtLLcHemEKfxYe2XjYM9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733f1e084829f5f8d4498eb796',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023f1e084829f5f8d4498eb796',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513f1e084829f5f8d4498eb796',
#       'width': 64}],
#     'name': 'Arijit Sharma',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:2qVtLLcHemEKfxYe2XjYM9'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6FTjcDq8hIGmmxiK4zL6oW'},
#     'followers': {'href': None, 'total': 0},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/6FTjcDq8hIGmmxiK4zL6oW',
#     'id': '6FTjcDq8hIGmmxiK4zL6oW',
#     'images': [],
#     'name': 'Orquesta de Carlos Arijita',
#     'popularity': 2,
#     'type': 'artist',
#     'uri': 'spotify:artist:6FTjcDq8hIGmmxiK4zL6oW'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5tv7VA6Y8iLcRPUD26gkdK'},
#     'followers': {'href': None, 'total': 3},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/5tv7VA6Y8iLcRPUD26gkdK',
#     'id': '5tv7VA6Y8iLcRPUD26gkdK',
#     'images': [],
#     'name': 'Arijit Bhattacharya',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:5tv7VA6Y8iLcRPUD26gkdK'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=arijit&type=artist&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 63}}
